# %%
x = 'Python'
y = 'is'
z = 'awesom'
print(x, y, z)
# Out:
# Python is awesom

# %%
x = 'Python'
y = 'is'
z = 'awesom'
print(x + y + z)
# Out:
# Pythonisawesom

# %%
# Adding two number
x = 15
y = 10
print(x + y)
# Out:
# 25

# %%
x = 5
y = 'yadav'
print(x + y)  # we can not add string and integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 x = 5
#       2 y = 'yadav'
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 5
y = 'yadav'
print(x, y)
# Out:
# 5 yadav
