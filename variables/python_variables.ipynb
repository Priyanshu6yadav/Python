# %% [markdown]
# ### Creating Variables

# %%
x = 5
y = 'shu'
print(x)
print(y)
# Out:
# 5
# shu

# %%
y = 4
y = "priyanshu"
print(y)
# Out:
# priyanshu

# %%
### Casting
x = str(3)
y = int(3)
z = float(3)
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
## Case - sensitive
# A will not overwrite a
a = 4
A = 'hero'
print(a)
print(A)
# Out:
# 4
# hero
