# %%
## Q1. Basic Arithmetic
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)

# %%
# Q2 odd or even
num = int(input("Enter a number: "))
if num %2 ==0:
    print('Even')
else:
    print("odd")

# %%
# Q3 Greater of two number
A = int(input("Enter first number:"))
B = int(input("Enter second number "))
if A>B :
    print("A is greater then b")
elif B>A:
    print("B is grater then A")
else:
    print("Both are euqal")
# Out:
# B is grater then A

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
op = input("Enter operator (+, -, *, /, //, %, **): ")

if op == '+':
    print("Result:", a + b)
elif op == '-':
    print("Result:", a - b)
elif op == '*':
    print("Result:", a * b)
elif op == '/':
    print("Result:", a / b)
elif op == '//':
    print("Result:", a // b)
elif op == '%':
    print("Result:", a % b)
elif op == '**':
    print("Result:", a ** b)
else:
    print("Invalid operator!")
# Out:
# Result:  49.0

# %%
## Q A number is devisible by 3 and 5
number = int(input("Enter a number"))
if number %3==0 and number %5==0:
    print("number is divided by 3 and 5")
else:
    print("Not divided by 3 and 5")
# Out:
# Not divided by 3 and 5

# %%
# divisible by 7 but not by 10.
number = int(input("Enter a number"))
if number %7==0 and number %10 !=0:
    print("number is divided by 7")
elif number %7==0 and number %10 ==0:
    print("Number divided my both 7 and 10")
elif number %7 !=0 and number % 10 ==0:
    print("only divisible by 10 not 7")
else:
    print("not divide by both 7 and 10")
# Out:
# number is divided by 7
